# %% [markdown]
# <a href="https://colab.research.google.com/github/ArvinAz/Python/blob/main/HW10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #List and Tuples#

# %%
#https://raw.githubusercontent.com/MatthewFried/Udemy/master/Day1/Day1_Data.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/MatthewFried/Udemy/master/Day1/Day1_Data.csv")
df.head()
# Out:
#        T      V       AP     RH      EP
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
#stats on my data
df.isnull().sum()
df.describe()
# Out:
#                  T            V           AP           RH           EP
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
df.isna().sum()
# Out:
# T     0
# V     0
# AP    0
# RH    0
# EP    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# T     0
# V     0
# AP    0
# RH    0
# EP    0
# dtype: int64

# %%
sns.catplot(data=df, kind = 'box', height = 7, aspect = 2)

# %%
 sns.catplot(x='T',data = df,kind = 'count',height = 3, aspect = 1.1 )

# %%
df.hist(figsize= (15,10), bins = 20, xlabelsize= 10,ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4e295945d0>,
# ...
#       dtype=object)

# %%
import plotly.express as px

fig = px.scatter(df, x="T", y="V", color="EP")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Program to plot 2-D Heat map
# using seaborn.heatmap() method
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
  
data_set = np.random.rand( 9568 , 9568)
ax = sns.heatmap( df , linewidth = 0.5 , cmap = 'coolwarm' )
  
plt.title( "2-D Heat Map" )
plt.show()

# %% [markdown]
# ####2: Data science refers to the way of discovering useful information from data using computer science. The process of data science has produced BIG data so to answer questions, it requires sophisticated data infrastructure and parallel computing
# ####3: Difference between lists and tuples is that a lists elements can be changed an can be any data type but a tuple cannot be changed and a tuple's elements must be the same data type.
# ####4:
# ####scrikit learn: contains a lot of efficient tools for machine learning and statistical modeling including classification, regression, clustering and dimensionality reduction.
# ####pandas: is used to transport files or code from another website or file.
# ####Tensorglow: It includes a feature of that defines, optimizes and calculates mathematical expressions easily with the help of multi-dimensional arrays called tensors.
# ####numpy:used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.
# ####tkinter: helps in creating GUI applications in a fast and easy way.
